# %%
from src.dataset import load_dataset,create_feuture,save_processed_dataset
import pandas as pd

# %% [markdown]
# Creazione datset per la regressione Polinomiali

# %%
import pandas as pd

TRAIN_PATH_X="../../data/raw/train/X_train.csv"
TRAIN_PATH_Y="../../data/raw/train/y_train.csv"

df_X_train=load_dataset(TRAIN_PATH_X)
df_y_train=load_dataset(TRAIN_PATH_Y)

df= pd.merge(df_X_train,df_y_train,on="id").drop("id", axis=1)
df=create_feuture(df)
save_processed_dataset(df,path="../../data/processed/train/train.csv",drop_feuture=['faulty','trq_margin','np','ng'],name="s")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 TRAIN_PATH_X="../../data/raw/train/X_train.csv"
#       4 TRAIN_PATH_Y="../../data/raw/train/y_train.csv"
# ----> 6 df_X_train=load_dataset(TRAIN_PATH_X)
#       7 df_y_train=load_dataset(TRAIN_PATH_Y)
#       9 df= pd.merge(df_X_train,df_y_train,on="id").drop("id", axis=1)
#
# NameError: name 'load_dataset' is not defined
